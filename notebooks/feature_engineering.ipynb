# %% [markdown]
# # Библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

# %% [markdown]
# # Загрузка данных

# %%
train = pd.read_csv('../data/processed/data_after_EDA.csv', low_memory=False)

# %% [markdown]
# # Генерация новых признаков

# %%
train
# Out:
#        Month   Age          SSN  Monthly_Inhand_Salary  Num_of_Loan  \
# 0          1  23.0  821-00-0265                   1824          4.0
# 1          2  23.0  821-00-0265                   3093          4.0
# 2          3  33.0  821-00-0265                   3093          4.0
# 3          4  23.0  821-00-0265                   3093          4.0
# 4          5  23.0  821-00-0265                   1824          4.0
# ...      ...   ...          ...                    ...          ...
# 99995      4  25.0  078-73-5990                   3359          2.0
# 99996      5  25.0  078-73-5990                   3359          2.0
# 99997      6  25.0  078-73-5990                   3359          2.0
# 99998      7  25.0  078-73-5990                   3359          2.0
# 99999      8  25.0  078-73-5990                   3359          2.0
#
#        Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                      3.0                     7.0                 11.27
# ...

# %%
train.columns
# Out:
# Index(['Month', 'Age', 'SSN', 'Monthly_Inhand_Salary', 'Num_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Outstanding_Debt', 'Credit_Utilization_Ratio',
#        'Credit_History_Age', 'Amount_invested_monthly', 'Monthly_Balance',
#        'Credit_Score', 'NM', 'No', 'Yes', 'High_spent_Large_value_payments',
#        'High_spent_Medium_value_payments', 'High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments', 'Low_spent_Medium_value_payments',
#        'Low_spent_Small_value_payments', 'unknown', 'Bad', 'Good', 'NoData',
#        'Standard'],
#       dtype='object')

# %% [markdown]
# ### Создадим призна, отражающий изменнение ежемесячной зарплаты отностильно наименьшего значения для каждого клиента

# %%
train['Salary_Vector'] = train.groupby('SSN')['Monthly_Inhand_Salary'].rank()

# %%
train
# Out:
#        Month   Age          SSN  Monthly_Inhand_Salary  Num_of_Loan  \
# 0          1  23.0  821-00-0265                   1824          4.0
# 1          2  23.0  821-00-0265                   3093          4.0
# 2          3  33.0  821-00-0265                   3093          4.0
# 3          4  23.0  821-00-0265                   3093          4.0
# 4          5  23.0  821-00-0265                   1824          4.0
# ...      ...   ...          ...                    ...          ...
# 99995      4  25.0  078-73-5990                   3359          2.0
# 99996      5  25.0  078-73-5990                   3359          2.0
# 99997      6  25.0  078-73-5990                   3359          2.0
# 99998      7  25.0  078-73-5990                   3359          2.0
# 99999      8  25.0  078-73-5990                   3359          2.0
#
#        Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                      3.0                     7.0                 11.27
# ...

# %% [markdown]
# ### Сделаем то же самое для коэфицента использования кредитной картой

# %%
train['Credit_Card_Usage_Vector'] = train.groupby('SSN')['Credit_Utilization_Ratio'].rank()

# %% [markdown]
# ### Удалим колонку с идентефикатором клиента, так как он нам больше не нужен. Вдобавок признак может сильно испортить качество модели, так как она начнет классифицировать пользователей относительно этой фичи

# %%
train = train.drop('SSN', axis=1)

# %% [markdown]
# # Сохраним данные

# %%
train.to_csv('../data/processed/featured_data.csv', index=False)
